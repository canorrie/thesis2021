# %%
#import libraries
import pandas as pd
import numpy as np
from google.colab import files
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import preprocessing
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
#upload dataset, drop rows with missing values, drop columns that would be impossible to determine upon presentation or aggregate features
uploaded = files.upload()
df = pd.read_csv(open("SepsisBiomarkersProcessed.csv", "r"))
df = df.drop(columns=['Unnamed: 0'])
df = df.replace(-1,np.NaN)
df = df.dropna()
df = df.drop(columns = ['28 days survival (yes/no)', 'Positve blood culture (yes/no)', 'Proven bacterial infection (yes/no)', 'Bacterial sepsis using Sepsis-2 criteria (yes/no/cannot be determined)', 'Severe bacterial sepsis/septic shock using Sepsis-2 criteria (yes/no/cannot be determined)', 'Intensive care unit (yes/no)', 'Systemic inflammatory response syndrome (yes/no/cannot be determined)', 'SOFA score ≥2 (yes/no)'])

# %%
#simple logistic regression model
def logistic_regression_model(df_arg, train_size):
  X_train, X_test, y_train, y_test = train_test_split(df_arg.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1), 
                                                    df_arg['Bacterial sepsis using Sepsis-3 criteria (yes/no)'], 
                                                    test_size=1-train_size, 
                                                    random_state = 10000)
  model = LogisticRegression(max_iter = 1000)
  model.fit(X_train, y_train)
  predictions = model.predict(X_test)

  print(classification_report(y_test,predictions))

  return model

# %%
#train model and assign to variable
logreg_model = logistic_regression_model(df, 0.8)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.86      0.78       146
#          1.0       0.67      0.45      0.54        93
#
#     accuracy                           0.70       239
#    macro avg       0.69      0.65      0.66       239
# weighted avg       0.69      0.70      0.68       239

# %%
#format for predictions
single_prediction = np.array([50.0, 1, 100, 33.0, 93.0, 74.0, 38, 87, 15, 300.0, 0.46, 10.7, 1.86]).reshape(1, -1)
logreg_model.predict(single_prediction)
# Out:
# array([0.])

# %%
def NN_function(df_arg, train_size, number_of_layers, number_of_epochs, activation_function):

  dfx = df_arg.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)
  dfy = df_arg['Bacterial sepsis using Sepsis-3 criteria (yes/no)']
  X_train, X_test, y_train, y_test = train_test_split(dfx, dfy, test_size=1-train_size, random_state = 10000)  

  trainxr = X_train.values.astype('float32')
  testxr = X_test.values.astype('float32')
  trainy = y_train.values.astype('float32')
  testy = y_test.values.astype('float32')

  model = keras.Sequential()

  n_layer = keras.layers.experimental.preprocessing.Normalization()
  n_layer.adapt(trainxr)
#  n_layer(testxr)

#  model.add(layers.Lambda(lambda x: keras.utils.normalize(x,axis=1)))
  model.add(n_layer)

  if (number_of_layers!=1):
    for i in range(number_of_layers-1):
      model.add(layers.Dense(32, activation=activation_function))
    model.add(layers.Dense(32, activation=activation_function))

  model.add(layers.Dense(1, activation='sigmoid'))

  opt = keras.optimizers.Adam(lr=0.0005)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

  history = model.fit(trainxr, trainy, epochs=number_of_epochs, batch_size=64, validation_data=(testxr, testy), verbose=2, shuffle=True)

  #plot the loss values 
  plt.plot(history.history['loss'], label='Training loss')
  plt.plot(history.history['val_loss'], label='Test loss')
  plt.legend()
  plt.show()

  #evaluation
  prediction_vector = model.predict(testxr)
  index = 0
  correct = 0
  for i in np.around(prediction_vector):
    if i == testy[index]:
      correct+=1
    index+=1
  print("Accuracy:", correct/(index+1))

  print(model.summary())

  return model

# %%
nn_model = NN_function(df, 0.75, 2, 150, 'sigmoid')
# Out:
# Epoch 1/150
# 14/14 - 1s - loss: 0.6532 - accuracy: 0.6480 - val_loss: 0.6685 - val_accuracy: 0.5987
# Epoch 2/150
# 14/14 - 0s - loss: 0.6436 - accuracy: 0.6492 - val_loss: 0.6725 - val_accuracy: 0.5987
# Epoch 3/150
# 14/14 - 0s - loss: 0.6388 - accuracy: 0.6492 - val_loss: 0.6705 - val_accuracy: 0.5987
# Epoch 4/150
# 14/14 - 0s - loss: 0.6364 - accuracy: 0.6492 - val_loss: 0.6665 - val_accuracy: 0.5987
# Epoch 5/150
# 14/14 - 0s - loss: 0.6337 - accuracy: 0.6492 - val_loss: 0.6629 - val_accuracy: 0.5987
# Epoch 6/150
# 14/14 - 0s - loss: 0.6310 - accuracy: 0.6492 - val_loss: 0.6611 - val_accuracy: 0.5987
# Epoch 7/150
# 14/14 - 0s - loss: 0.6282 - accuracy: 0.6492 - val_loss: 0.6577 - val_accuracy: 0.5987
# Epoch 8/150
# 14/14 - 0s - loss: 0.6252 - accuracy: 0.6492 - val_loss: 0.6525 - val_accuracy: 0.5987
# Epoch 9/150
# 14/14 - 0s - loss: 0.6222 - accuracy: 0.6492 - val_loss: 0.6489 - val_accuracy: 0.5987
# Epoch 10/150
# 14/14 - 0s - loss: 0.6188 - accuracy: 0.6514 - val_loss: 0.6451 - val_accuracy: 0.5987
# Epoch 11/150
# 14/14 - 0s - loss: 0.6151 - accuracy: 0.6514 - val_loss: 0.6422 - val_accuracy: 0.5987
# Epoch 12/150
# 14/14 - 0s - loss: 0.6119 - accuracy: 0.6514 - val_loss: 0.6381 - val_accuracy: 0.5987
# Epoch 13/150
# 14/14 - 0s - loss: 0.6079 - accuracy: 0.6525 - val_loss: 0.6338 - val_accuracy: 0.6020
# Epoch 14/150
# 14/14 - 0s - loss: 0.6040 - accuracy: 0.6570 - val_loss: 0.6302 - val_accuracy: 0.6154
# Epoch 15/150
# 14/14 - 0s - loss: 0.6002 - accuracy: 0.6615 - val_loss: 0.6243 - val_accuracy: 0.6288
# Epoch 16/150
# 14/14 - 0s - loss: 0.5959 - accuracy: 0.6659 - val_loss: 0.6197 - val_accuracy: 0.6321
# Epoch 17/150
# 14/14 - 0s - loss: 0.5918 - accuracy: 0.6693 - val_loss: 0.6145 - val_accuracy: 0.6421
# Epoch 18/150
# 14/14 - 0s - loss: 0.5878 - accuracy: 0.6827 - val_loss: 0.6089 - val_accuracy: 0.6555
# Epoch 19/150
# 14/14 - 0s - loss: 0.5836 - accuracy: 0.6905 - val_loss: 0.6039 - val_accuracy: 0.6522
# Epoch 20/150
# 14/14 - 0s - loss: 0.5794 - accuracy: 0.6961 - val_loss: 0.6000 - val_accuracy: 0.6589
# Epoch 21/150
# 14/14 - 0s - loss: 0.5757 - accuracy: 0.6994 - val_loss: 0.5967 - val_accuracy: 0.6656
# Epoch 22/150
# 14/14 - 0s - loss: 0.5721 - accuracy: 0.7073 - val_loss: 0.5923 - val_accuracy: 0.6689
# Epoch 23/150
# 14/14 - 0s - loss: 0.5682 - accuracy: 0.7084 - val_loss: 0.5868 - val_accuracy: 0.6923
# Epoch 24/150
# 14/14 - 0s - loss: 0.5649 - accuracy: 0.7073 - val_loss: 0.5819 - val_accuracy: 0.7057
# Epoch 25/150
# 14/14 - 0s - loss: 0.5618 - accuracy: 0.7084 - val_loss: 0.5789 - val_accuracy: 0.7124
# Epoch 26/150
# 14/14 - 0s - loss: 0.5588 - accuracy: 0.7095 - val_loss: 0.5752 - val_accuracy: 0.7057
# Epoch 27/150
# 14/14 - 0s - loss: 0.5564 - accuracy: 0.7095 - val_loss: 0.5718 - val_accuracy: 0.7057
# Epoch 28/150
# 14/14 - 0s - loss: 0.5543 - accuracy: 0.7095 - val_loss: 0.5697 - val_accuracy: 0.7057
# Epoch 29/150
# 14/14 - 0s - loss: 0.5518 - accuracy: 0.7173 - val_loss: 0.5657 - val_accuracy: 0.7157
# Epoch 30/150
# 14/14 - 0s - loss: 0.5497 - accuracy: 0.7207 - val_loss: 0.5636 - val_accuracy: 0.7191
# Epoch 31/150
# 14/14 - 0s - loss: 0.5479 - accuracy: 0.7218 - val_loss: 0.5616 - val_accuracy: 0.7191
# Epoch 32/150
# 14/14 - 0s - loss: 0.5469 - accuracy: 0.7218 - val_loss: 0.5606 - val_accuracy: 0.7224
# Epoch 33/150
# 14/14 - 0s - loss: 0.5452 - accuracy: 0.7240 - val_loss: 0.5574 - val_accuracy: 0.7258
# Epoch 34/150
# 14/14 - 0s - loss: 0.5439 - accuracy: 0.7240 - val_loss: 0.5562 - val_accuracy: 0.7291
# Epoch 35/150
# 14/14 - 0s - loss: 0.5428 - accuracy: 0.7240 - val_loss: 0.5546 - val_accuracy: 0.7258
# Epoch 36/150
# 14/14 - 0s - loss: 0.5418 - accuracy: 0.7240 - val_loss: 0.5538 - val_accuracy: 0.7258
# Epoch 37/150
# 14/14 - 0s - loss: 0.5410 - accuracy: 0.7274 - val_loss: 0.5519 - val_accuracy: 0.7358
# Epoch 38/150
# 14/14 - 0s - loss: 0.5402 - accuracy: 0.7296 - val_loss: 0.5512 - val_accuracy: 0.7358
# Epoch 39/150
# 14/14 - 0s - loss: 0.5396 - accuracy: 0.7274 - val_loss: 0.5511 - val_accuracy: 0.7324
# Epoch 40/150
# 14/14 - 0s - loss: 0.5389 - accuracy: 0.7285 - val_loss: 0.5502 - val_accuracy: 0.7358
# Epoch 41/150
# 14/14 - 0s - loss: 0.5387 - accuracy: 0.7229 - val_loss: 0.5479 - val_accuracy: 0.7291
# Epoch 42/150
# 14/14 - 0s - loss: 0.5379 - accuracy: 0.7240 - val_loss: 0.5478 - val_accuracy: 0.7291
# Epoch 43/150
# 14/14 - 0s - loss: 0.5374 - accuracy: 0.7263 - val_loss: 0.5476 - val_accuracy: 0.7291
# Epoch 44/150
# 14/14 - 0s - loss: 0.5370 - accuracy: 0.7240 - val_loss: 0.5476 - val_accuracy: 0.7291
# Epoch 45/150
# 14/14 - 0s - loss: 0.5367 - accuracy: 0.7263 - val_loss: 0.5469 - val_accuracy: 0.7291
# Epoch 46/150
# 14/14 - 0s - loss: 0.5364 - accuracy: 0.7263 - val_loss: 0.5468 - val_accuracy: 0.7291
# Epoch 47/150
# 14/14 - 0s - loss: 0.5361 - accuracy: 0.7285 - val_loss: 0.5460 - val_accuracy: 0.7324
# Epoch 48/150
# 14/14 - 0s - loss: 0.5359 - accuracy: 0.7263 - val_loss: 0.5458 - val_accuracy: 0.7324
# Epoch 49/150
# 14/14 - 0s - loss: 0.5356 - accuracy: 0.7251 - val_loss: 0.5444 - val_accuracy: 0.7358
# Epoch 50/150
# 14/14 - 0s - loss: 0.5352 - accuracy: 0.7274 - val_loss: 0.5445 - val_accuracy: 0.7358
# Epoch 51/150
# 14/14 - 0s - loss: 0.5350 - accuracy: 0.7285 - val_loss: 0.5447 - val_accuracy: 0.7358
# Epoch 52/150
# 14/14 - 0s - loss: 0.5349 - accuracy: 0.7251 - val_loss: 0.5443 - val_accuracy: 0.7324
# Epoch 53/150
# 14/14 - 0s - loss: 0.5346 - accuracy: 0.7296 - val_loss: 0.5447 - val_accuracy: 0.7358
# Epoch 54/150
# 14/14 - 0s - loss: 0.5344 - accuracy: 0.7274 - val_loss: 0.5439 - val_accuracy: 0.7358
# Epoch 55/150
# 14/14 - 0s - loss: 0.5343 - accuracy: 0.7263 - val_loss: 0.5443 - val_accuracy: 0.7358
# Epoch 56/150
# 14/14 - 0s - loss: 0.5341 - accuracy: 0.7274 - val_loss: 0.5435 - val_accuracy: 0.7358
# Epoch 57/150
# 14/14 - 0s - loss: 0.5338 - accuracy: 0.7274 - val_loss: 0.5431 - val_accuracy: 0.7324
# Epoch 58/150
# 14/14 - 0s - loss: 0.5338 - accuracy: 0.7285 - val_loss: 0.5432 - val_accuracy: 0.7324
# Epoch 59/150
# 14/14 - 0s - loss: 0.5338 - accuracy: 0.7285 - val_loss: 0.5440 - val_accuracy: 0.7358
# Epoch 60/150
# 14/14 - 0s - loss: 0.5335 - accuracy: 0.7285 - val_loss: 0.5433 - val_accuracy: 0.7324
# Epoch 61/150
# 14/14 - 0s - loss: 0.5333 - accuracy: 0.7263 - val_loss: 0.5429 - val_accuracy: 0.7324
# Epoch 62/150
# 14/14 - 0s - loss: 0.5335 - accuracy: 0.7307 - val_loss: 0.5420 - val_accuracy: 0.7291
# Epoch 63/150
# 14/14 - 0s - loss: 0.5331 - accuracy: 0.7296 - val_loss: 0.5434 - val_accuracy: 0.7324
# Epoch 64/150
# 14/14 - 0s - loss: 0.5328 - accuracy: 0.7274 - val_loss: 0.5430 - val_accuracy: 0.7324
# Epoch 65/150
# 14/14 - 0s - loss: 0.5328 - accuracy: 0.7296 - val_loss: 0.5427 - val_accuracy: 0.7291
# Epoch 66/150
# 14/14 - 0s - loss: 0.5334 - accuracy: 0.7307 - val_loss: 0.5416 - val_accuracy: 0.7291
# Epoch 67/150
# 14/14 - 0s - loss: 0.5334 - accuracy: 0.7274 - val_loss: 0.5444 - val_accuracy: 0.7425
# Epoch 68/150
# 14/14 - 0s - loss: 0.5324 - accuracy: 0.7274 - val_loss: 0.5435 - val_accuracy: 0.7324
# Epoch 69/150
# 14/14 - 0s - loss: 0.5322 - accuracy: 0.7296 - val_loss: 0.5423 - val_accuracy: 0.7324
# Epoch 70/150
# 14/14 - 0s - loss: 0.5327 - accuracy: 0.7363 - val_loss: 0.5412 - val_accuracy: 0.7291
# Epoch 71/150
# 14/14 - 0s - loss: 0.5323 - accuracy: 0.7318 - val_loss: 0.5428 - val_accuracy: 0.7291
# Epoch 72/150
# 14/14 - 0s - loss: 0.5321 - accuracy: 0.7307 - val_loss: 0.5420 - val_accuracy: 0.7324
# Epoch 73/150
# 14/14 - 0s - loss: 0.5318 - accuracy: 0.7318 - val_loss: 0.5427 - val_accuracy: 0.7291
# Epoch 74/150
# 14/14 - 0s - loss: 0.5318 - accuracy: 0.7296 - val_loss: 0.5426 - val_accuracy: 0.7291
# Epoch 75/150
# 14/14 - 0s - loss: 0.5317 - accuracy: 0.7330 - val_loss: 0.5421 - val_accuracy: 0.7358
# Epoch 76/150
# 14/14 - 0s - loss: 0.5317 - accuracy: 0.7307 - val_loss: 0.5426 - val_accuracy: 0.7258
# Epoch 77/150
# 14/14 - 0s - loss: 0.5317 - accuracy: 0.7307 - val_loss: 0.5414 - val_accuracy: 0.7324
# Epoch 78/150
# 14/14 - 0s - loss: 0.5321 - accuracy: 0.7318 - val_loss: 0.5429 - val_accuracy: 0.7291
# Epoch 79/150
# 14/14 - 0s - loss: 0.5324 - accuracy: 0.7318 - val_loss: 0.5406 - val_accuracy: 0.7258
# Epoch 80/150
# 14/14 - 0s - loss: 0.5310 - accuracy: 0.7352 - val_loss: 0.5418 - val_accuracy: 0.7291
# Epoch 81/150
# 14/14 - 0s - loss: 0.5316 - accuracy: 0.7307 - val_loss: 0.5434 - val_accuracy: 0.7324
# Epoch 82/150
# 14/14 - 0s - loss: 0.5311 - accuracy: 0.7318 - val_loss: 0.5416 - val_accuracy: 0.7291
# Epoch 83/150
# 14/14 - 0s - loss: 0.5310 - accuracy: 0.7352 - val_loss: 0.5411 - val_accuracy: 0.7291
# Epoch 84/150
# 14/14 - 0s - loss: 0.5308 - accuracy: 0.7307 - val_loss: 0.5422 - val_accuracy: 0.7358
# Epoch 85/150
# 14/14 - 0s - loss: 0.5307 - accuracy: 0.7318 - val_loss: 0.5420 - val_accuracy: 0.7324
# Epoch 86/150
# 14/14 - 0s - loss: 0.5306 - accuracy: 0.7341 - val_loss: 0.5423 - val_accuracy: 0.7324
# Epoch 87/150
# 14/14 - 0s - loss: 0.5308 - accuracy: 0.7341 - val_loss: 0.5430 - val_accuracy: 0.7324
# Epoch 88/150
# 14/14 - 0s - loss: 0.5305 - accuracy: 0.7330 - val_loss: 0.5414 - val_accuracy: 0.7291
# Epoch 89/150
# 14/14 - 0s - loss: 0.5304 - accuracy: 0.7341 - val_loss: 0.5415 - val_accuracy: 0.7324
# Epoch 90/150
# 14/14 - 0s - loss: 0.5305 - accuracy: 0.7307 - val_loss: 0.5425 - val_accuracy: 0.7358
# Epoch 91/150
# 14/14 - 0s - loss: 0.5302 - accuracy: 0.7341 - val_loss: 0.5415 - val_accuracy: 0.7324
# Epoch 92/150
# 14/14 - 0s - loss: 0.5303 - accuracy: 0.7341 - val_loss: 0.5405 - val_accuracy: 0.7358
# Epoch 93/150
# 14/14 - 0s - loss: 0.5300 - accuracy: 0.7341 - val_loss: 0.5415 - val_accuracy: 0.7324
# Epoch 94/150
# 14/14 - 0s - loss: 0.5299 - accuracy: 0.7330 - val_loss: 0.5421 - val_accuracy: 0.7358
# Epoch 95/150
# 14/14 - 0s - loss: 0.5298 - accuracy: 0.7341 - val_loss: 0.5424 - val_accuracy: 0.7358
# Epoch 96/150
# 14/14 - 0s - loss: 0.5299 - accuracy: 0.7318 - val_loss: 0.5422 - val_accuracy: 0.7358
# Epoch 97/150
# 14/14 - 0s - loss: 0.5299 - accuracy: 0.7352 - val_loss: 0.5407 - val_accuracy: 0.7291
# Epoch 98/150
# 14/14 - 0s - loss: 0.5300 - accuracy: 0.7318 - val_loss: 0.5422 - val_accuracy: 0.7324
# Epoch 99/150
# 14/14 - 0s - loss: 0.5295 - accuracy: 0.7330 - val_loss: 0.5416 - val_accuracy: 0.7324
# Epoch 100/150
# 14/14 - 0s - loss: 0.5296 - accuracy: 0.7352 - val_loss: 0.5408 - val_accuracy: 0.7324
# Epoch 101/150
# 14/14 - 0s - loss: 0.5295 - accuracy: 0.7363 - val_loss: 0.5417 - val_accuracy: 0.7324
# Epoch 102/150
# 14/14 - 0s - loss: 0.5293 - accuracy: 0.7341 - val_loss: 0.5413 - val_accuracy: 0.7324
# Epoch 103/150
# 14/14 - 0s - loss: 0.5296 - accuracy: 0.7341 - val_loss: 0.5421 - val_accuracy: 0.7324
# Epoch 104/150
# 14/14 - 0s - loss: 0.5294 - accuracy: 0.7363 - val_loss: 0.5414 - val_accuracy: 0.7324
# Epoch 105/150
# 14/14 - 0s - loss: 0.5291 - accuracy: 0.7363 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 106/150
# 14/14 - 0s - loss: 0.5294 - accuracy: 0.7341 - val_loss: 0.5427 - val_accuracy: 0.7358
# Epoch 107/150
# 14/14 - 0s - loss: 0.5290 - accuracy: 0.7363 - val_loss: 0.5413 - val_accuracy: 0.7358
# Epoch 108/150
# 14/14 - 0s - loss: 0.5290 - accuracy: 0.7352 - val_loss: 0.5403 - val_accuracy: 0.7391
# Epoch 109/150
# 14/14 - 0s - loss: 0.5288 - accuracy: 0.7352 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 110/150
# 14/14 - 0s - loss: 0.5287 - accuracy: 0.7352 - val_loss: 0.5415 - val_accuracy: 0.7324
# Epoch 111/150
# 14/14 - 0s - loss: 0.5287 - accuracy: 0.7374 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 112/150
# 14/14 - 0s - loss: 0.5286 - accuracy: 0.7363 - val_loss: 0.5414 - val_accuracy: 0.7324
# Epoch 113/150
# 14/14 - 0s - loss: 0.5289 - accuracy: 0.7330 - val_loss: 0.5422 - val_accuracy: 0.7324
# Epoch 114/150
# 14/14 - 0s - loss: 0.5285 - accuracy: 0.7341 - val_loss: 0.5407 - val_accuracy: 0.7358
# Epoch 115/150
# 14/14 - 0s - loss: 0.5284 - accuracy: 0.7363 - val_loss: 0.5406 - val_accuracy: 0.7324
# Epoch 116/150
# 14/14 - 0s - loss: 0.5283 - accuracy: 0.7352 - val_loss: 0.5409 - val_accuracy: 0.7324
# Epoch 117/150
# 14/14 - 0s - loss: 0.5283 - accuracy: 0.7374 - val_loss: 0.5416 - val_accuracy: 0.7358
# Epoch 118/150
# 14/14 - 0s - loss: 0.5283 - accuracy: 0.7341 - val_loss: 0.5412 - val_accuracy: 0.7324
# Epoch 119/150
# 14/14 - 0s - loss: 0.5281 - accuracy: 0.7374 - val_loss: 0.5409 - val_accuracy: 0.7324
# Epoch 120/150
# 14/14 - 0s - loss: 0.5280 - accuracy: 0.7374 - val_loss: 0.5405 - val_accuracy: 0.7358
# Epoch 121/150
# 14/14 - 0s - loss: 0.5281 - accuracy: 0.7374 - val_loss: 0.5410 - val_accuracy: 0.7324
# Epoch 122/150
# 14/14 - 0s - loss: 0.5279 - accuracy: 0.7374 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 123/150
# 14/14 - 0s - loss: 0.5283 - accuracy: 0.7285 - val_loss: 0.5419 - val_accuracy: 0.7324
# Epoch 124/150
# 14/14 - 0s - loss: 0.5278 - accuracy: 0.7341 - val_loss: 0.5414 - val_accuracy: 0.7358
# Epoch 125/150
# 14/14 - 0s - loss: 0.5279 - accuracy: 0.7408 - val_loss: 0.5397 - val_accuracy: 0.7358
# Epoch 126/150
# 14/14 - 0s - loss: 0.5277 - accuracy: 0.7374 - val_loss: 0.5407 - val_accuracy: 0.7324
# Epoch 127/150
# 14/14 - 0s - loss: 0.5277 - accuracy: 0.7363 - val_loss: 0.5409 - val_accuracy: 0.7324
# Epoch 128/150
# 14/14 - 0s - loss: 0.5275 - accuracy: 0.7363 - val_loss: 0.5406 - val_accuracy: 0.7324
# Epoch 129/150
# 14/14 - 0s - loss: 0.5274 - accuracy: 0.7374 - val_loss: 0.5408 - val_accuracy: 0.7358
# Epoch 130/150
# 14/14 - 0s - loss: 0.5274 - accuracy: 0.7374 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 131/150
# 14/14 - 0s - loss: 0.5278 - accuracy: 0.7352 - val_loss: 0.5420 - val_accuracy: 0.7324
# Epoch 132/150
# 14/14 - 0s - loss: 0.5271 - accuracy: 0.7318 - val_loss: 0.5411 - val_accuracy: 0.7324
# Epoch 133/150
# 14/14 - 0s - loss: 0.5271 - accuracy: 0.7374 - val_loss: 0.5402 - val_accuracy: 0.7324
# Epoch 134/150
# 14/14 - 0s - loss: 0.5275 - accuracy: 0.7397 - val_loss: 0.5397 - val_accuracy: 0.7358
# Epoch 135/150
# 14/14 - 0s - loss: 0.5273 - accuracy: 0.7363 - val_loss: 0.5414 - val_accuracy: 0.7291
# Epoch 136/150
# 14/14 - 0s - loss: 0.5270 - accuracy: 0.7330 - val_loss: 0.5416 - val_accuracy: 0.7291
# Epoch 137/150
# 14/14 - 0s - loss: 0.5269 - accuracy: 0.7330 - val_loss: 0.5415 - val_accuracy: 0.7291
# Epoch 138/150
# 14/14 - 0s - loss: 0.5268 - accuracy: 0.7363 - val_loss: 0.5406 - val_accuracy: 0.7291
# Epoch 139/150
# 14/14 - 0s - loss: 0.5270 - accuracy: 0.7374 - val_loss: 0.5397 - val_accuracy: 0.7425
# Epoch 140/150
# 14/14 - 0s - loss: 0.5271 - accuracy: 0.7385 - val_loss: 0.5397 - val_accuracy: 0.7425
# Epoch 141/150
# 14/14 - 0s - loss: 0.5265 - accuracy: 0.7352 - val_loss: 0.5414 - val_accuracy: 0.7291
# Epoch 142/150
# 14/14 - 0s - loss: 0.5267 - accuracy: 0.7330 - val_loss: 0.5418 - val_accuracy: 0.7324
# Epoch 143/150
# 14/14 - 0s - loss: 0.5267 - accuracy: 0.7341 - val_loss: 0.5405 - val_accuracy: 0.7324
# Epoch 144/150
# 14/14 - 0s - loss: 0.5265 - accuracy: 0.7363 - val_loss: 0.5408 - val_accuracy: 0.7291
# Epoch 145/150
# 14/14 - 0s - loss: 0.5263 - accuracy: 0.7374 - val_loss: 0.5403 - val_accuracy: 0.7324
# Epoch 146/150
# 14/14 - 0s - loss: 0.5266 - accuracy: 0.7374 - val_loss: 0.5400 - val_accuracy: 0.7324
# Epoch 147/150
# 14/14 - 0s - loss: 0.5265 - accuracy: 0.7363 - val_loss: 0.5411 - val_accuracy: 0.7291
# Epoch 148/150
# 14/14 - 0s - loss: 0.5268 - accuracy: 0.7352 - val_loss: 0.5398 - val_accuracy: 0.7291
# Epoch 149/150
# 14/14 - 0s - loss: 0.5261 - accuracy: 0.7363 - val_loss: 0.5405 - val_accuracy: 0.7291
# Epoch 150/150
# 14/14 - 0s - loss: 0.5268 - accuracy: 0.7352 - val_loss: 0.5424 - val_accuracy: 0.7291
# Accuracy: 0.7266666666666667
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_1 (Normalizati (None, 13)                27
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                448
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 1,564
# Trainable params: 1,537
# Non-trainable params: 27
# _________________________________________________________________
# None

# %%
#leftover code on how to make a set of predictions, the function returns a probability as to how likely it believes the person is septic
#uncomment the string literal to make this work
'''
dfnv_x = df.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)
dfnv_y = df['Bacterial sepsis using Sepsis-3 criteria (yes/no)']
X_train, X_test, y_train, y_test = train_test_split(dfnv_x, dfnv_y, test_size=0.25, random_state = 10000)  
trainxr = X_train.values.astype('float32')
testxr = X_test.values.astype('float32')
trainy = y_train.values.astype('float32')
testy = y_test.values.astype('float32')

prediction_vector = np.around(nn_model.predict(testxr))
prediction_vector
'''
# Out:
# "\ndfnv_x = df.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)\ndfnv_y = df['Bacterial sepsis using Sepsis-3 criteria (yes/no)']\nX_train, X_test, y_train, y_test = train_test_split(dfnv_x, dfnv_y, test_size=0.25, random_state = 10000)  \ntrainxr = X_train.values.astype('float32')\ntestxr = X_test.values.astype('float32')\ntrainy = y_train.values.astype('float32')\ntesty = y_test.values.astype('float32')\n\nprediction_vector = np.around(nn_model.predict(testxr))\nprediction_vector\n"
