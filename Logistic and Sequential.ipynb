# %%
#import libraries
import pandas as pd
import numpy as np
from google.colab import files
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn import preprocessing
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
#upload dataset, drop rows with missing values, drop columns that would be impossible to determine upon presentation or aggregate features
uploaded = files.upload()
df = pd.read_csv(open("SepsisBiomarkersProcessed.csv", "r"))
df = df.drop(columns=['Unnamed: 0'])
df = df.replace(-1,np.NaN)
df = df.dropna()
df = df.drop(columns = ['28 days survival (yes/no)', 'Positve blood culture (yes/no)', 'Proven bacterial infection (yes/no)', 'Bacterial sepsis using Sepsis-2 criteria (yes/no/cannot be determined)', 'Severe bacterial sepsis/septic shock using Sepsis-2 criteria (yes/no/cannot be determined)', 'Intensive care unit (yes/no)', 'Systemic inflammatory response syndrome (yes/no/cannot be determined)', 'SOFA score ≥2 (yes/no)'])
df.shape
# Out:
#      <input type="file" id="files-5eb83627-a366-4c48-985d-0f514148579b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5eb83627-a366-4c48-985d-0f514148579b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SepsisBiomarkersProcessed.csv to SepsisBiomarkersProcessed.csv
# (1194, 14)

# %%
df.columns
# Out:
# Index(['Age (years)', 'Gender (female/male)', 'Systolic blood pressure (mmHg)',
#        'Respiratory rate (breaths/min)', 'Oxygen saturation (%)',
#        'Heart rate (beats/min)', 'Body temperature (oC)', 'Haemoglobin (g/L)',
#        'Leukocyte particle concentration (x109 cells/L)',
#        'C-reactive protein (mg/L)', 'Procalcitonin (ng/mL)',
#        'Neutrophil-lymphocyte count ratio ', 'P-lactate (mmol/L)',
#        'Bacterial sepsis using Sepsis-3 criteria (yes/no)'],
#       dtype='object')

# %%
#simple logistic regression model
def logistic_regression_model(df_arg, train_size):
  X_train, X_test, y_train, y_test = train_test_split(df_arg.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1), 
                                                    df_arg['Bacterial sepsis using Sepsis-3 criteria (yes/no)'], 
                                                    test_size=1-train_size, 
                                                    random_state = 10000)
  model = LogisticRegression(max_iter = 1000)
  model.fit(X_train, y_train)
  predictions = model.predict(X_test)

  print(classification_report(y_test,predictions))

  return model

# %%
#train model and assign to variable
logreg_model = logistic_regression_model(df, 0.8)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.86      0.78       146
#          1.0       0.67      0.45      0.54        93
#
#     accuracy                           0.70       239
#    macro avg       0.69      0.65      0.66       239
# weighted avg       0.69      0.70      0.68       239

# %%
#format for predictions
single_prediction = np.array([50.0, 1, 100, 33.0, 93.0, 74.0, 38, 87, 15, 300.0, 0.46, 10.7, 1.86]).reshape(1, -1)
logreg_model.predict(single_prediction)
# Out:
# array([0.])

# %%
def NN_function(df_arg, train_size, number_of_layers, number_of_epochs, activation_function):
  
  nn_indices = df_arg.columns
  nn_np_values_array = df_arg.values
  nn_min_max_scaler = preprocessing.MinMaxScaler()
  nn_df_scaled_values = nn_min_max_scaler.fit_transform(nn_np_values_array)
  dfnv = pd.DataFrame(nn_df_scaled_values, columns = nn_indices)

  dfnv_x = dfnv.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)
  dfnv_y = dfnv['Bacterial sepsis using Sepsis-3 criteria (yes/no)']
  X_train, X_test, y_train, y_test = train_test_split(dfnv_x, dfnv_y, test_size=1-train_size, random_state = 10000)  

  trainxr = X_train.values.astype('float32')
  testxr = X_test.values.astype('float32')
  trainy = y_train.values.astype('float32')
  testy = y_test.values.astype('float32')

  model = keras.Sequential()

  if (number_of_layers!=1):
    for i in range(number_of_layers-1):
      model.add(layers.Dense(32, activation=activation_function))
    model.add(layers.Dense(32, activation=activation_function))

  model.add(layers.Dense(1, activation='sigmoid'))

  opt = keras.optimizers.Adam(lr=0.0005)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

  history = model.fit(trainxr, trainy, epochs=number_of_epochs, batch_size=64, validation_data=(testxr, testy), verbose=2, shuffle=True)

  #plot the loss values 
  plt.plot(history.history['loss'], label='Training loss')
  plt.plot(history.history['val_loss'], label='Test loss')
  plt.legend()
  plt.show()

  #evaluation
  prediction_vector = model.predict(testxr)
  index = 0
  correct = 0
  for i in np.around(prediction_vector):
    if i == testy[index]:
      correct+=1
    index+=1
  print("Accuracy:", correct/(index+1))

  print(model.summary())

  return model

# %%
nn_model = NN_function(df, 0.75, 2, 200, 'sigmoid')
# Out:
# Epoch 1/200
# 14/14 - 1s - loss: 0.6772 - accuracy: 0.6279 - val_loss: 0.6753 - val_accuracy: 0.5987
# Epoch 2/200
# 14/14 - 0s - loss: 0.6549 - accuracy: 0.6492 - val_loss: 0.6734 - val_accuracy: 0.5987
# Epoch 3/200
# 14/14 - 0s - loss: 0.6483 - accuracy: 0.6492 - val_loss: 0.6775 - val_accuracy: 0.5987
# Epoch 4/200
# 14/14 - 0s - loss: 0.6472 - accuracy: 0.6492 - val_loss: 0.6791 - val_accuracy: 0.5987
# Epoch 5/200
# 14/14 - 0s - loss: 0.6470 - accuracy: 0.6492 - val_loss: 0.6787 - val_accuracy: 0.5987
# Epoch 6/200
# 14/14 - 0s - loss: 0.6468 - accuracy: 0.6492 - val_loss: 0.6777 - val_accuracy: 0.5987
# Epoch 7/200
# 14/14 - 0s - loss: 0.6468 - accuracy: 0.6492 - val_loss: 0.6763 - val_accuracy: 0.5987
# Epoch 8/200
# 14/14 - 0s - loss: 0.6466 - accuracy: 0.6492 - val_loss: 0.6773 - val_accuracy: 0.5987
# Epoch 9/200
# 14/14 - 0s - loss: 0.6462 - accuracy: 0.6492 - val_loss: 0.6765 - val_accuracy: 0.5987
# Epoch 10/200
# 14/14 - 0s - loss: 0.6460 - accuracy: 0.6492 - val_loss: 0.6767 - val_accuracy: 0.5987
# Epoch 11/200
# 14/14 - 0s - loss: 0.6459 - accuracy: 0.6492 - val_loss: 0.6765 - val_accuracy: 0.5987
# Epoch 12/200
# 14/14 - 0s - loss: 0.6458 - accuracy: 0.6492 - val_loss: 0.6766 - val_accuracy: 0.5987
# Epoch 13/200
# 14/14 - 0s - loss: 0.6456 - accuracy: 0.6492 - val_loss: 0.6751 - val_accuracy: 0.5987
# Epoch 14/200
# 14/14 - 0s - loss: 0.6452 - accuracy: 0.6492 - val_loss: 0.6756 - val_accuracy: 0.5987
# Epoch 15/200
# 14/14 - 0s - loss: 0.6452 - accuracy: 0.6492 - val_loss: 0.6761 - val_accuracy: 0.5987
# Epoch 16/200
# 14/14 - 0s - loss: 0.6453 - accuracy: 0.6492 - val_loss: 0.6742 - val_accuracy: 0.5987
# Epoch 17/200
# 14/14 - 0s - loss: 0.6446 - accuracy: 0.6492 - val_loss: 0.6749 - val_accuracy: 0.5987
# Epoch 18/200
# 14/14 - 0s - loss: 0.6444 - accuracy: 0.6492 - val_loss: 0.6742 - val_accuracy: 0.5987
# Epoch 19/200
# 14/14 - 0s - loss: 0.6441 - accuracy: 0.6492 - val_loss: 0.6746 - val_accuracy: 0.5987
# Epoch 20/200
# 14/14 - 0s - loss: 0.6437 - accuracy: 0.6492 - val_loss: 0.6736 - val_accuracy: 0.5987
# Epoch 21/200
# 14/14 - 0s - loss: 0.6436 - accuracy: 0.6492 - val_loss: 0.6735 - val_accuracy: 0.5987
# Epoch 22/200
# 14/14 - 0s - loss: 0.6436 - accuracy: 0.6492 - val_loss: 0.6735 - val_accuracy: 0.5987
# Epoch 23/200
# 14/14 - 0s - loss: 0.6431 - accuracy: 0.6492 - val_loss: 0.6714 - val_accuracy: 0.5987
# Epoch 24/200
# 14/14 - 0s - loss: 0.6428 - accuracy: 0.6492 - val_loss: 0.6720 - val_accuracy: 0.5987
# Epoch 25/200
# 14/14 - 0s - loss: 0.6426 - accuracy: 0.6492 - val_loss: 0.6718 - val_accuracy: 0.5987
# Epoch 26/200
# 14/14 - 0s - loss: 0.6421 - accuracy: 0.6492 - val_loss: 0.6727 - val_accuracy: 0.5987
# Epoch 27/200
# 14/14 - 0s - loss: 0.6417 - accuracy: 0.6492 - val_loss: 0.6711 - val_accuracy: 0.5987
# Epoch 28/200
# 14/14 - 0s - loss: 0.6415 - accuracy: 0.6492 - val_loss: 0.6715 - val_accuracy: 0.5987
# Epoch 29/200
# 14/14 - 0s - loss: 0.6410 - accuracy: 0.6492 - val_loss: 0.6699 - val_accuracy: 0.5987
# Epoch 30/200
# 14/14 - 0s - loss: 0.6407 - accuracy: 0.6492 - val_loss: 0.6692 - val_accuracy: 0.5987
# Epoch 31/200
# 14/14 - 0s - loss: 0.6405 - accuracy: 0.6492 - val_loss: 0.6707 - val_accuracy: 0.5987
# Epoch 32/200
# 14/14 - 0s - loss: 0.6398 - accuracy: 0.6492 - val_loss: 0.6690 - val_accuracy: 0.5987
# Epoch 33/200
# 14/14 - 0s - loss: 0.6394 - accuracy: 0.6492 - val_loss: 0.6681 - val_accuracy: 0.5987
# Epoch 34/200
# 14/14 - 0s - loss: 0.6393 - accuracy: 0.6492 - val_loss: 0.6688 - val_accuracy: 0.5987
# Epoch 35/200
# 14/14 - 0s - loss: 0.6387 - accuracy: 0.6492 - val_loss: 0.6665 - val_accuracy: 0.5987
# Epoch 36/200
# 14/14 - 0s - loss: 0.6382 - accuracy: 0.6492 - val_loss: 0.6675 - val_accuracy: 0.5987
# Epoch 37/200
# 14/14 - 0s - loss: 0.6378 - accuracy: 0.6492 - val_loss: 0.6656 - val_accuracy: 0.5987
# Epoch 38/200
# 14/14 - 0s - loss: 0.6372 - accuracy: 0.6492 - val_loss: 0.6662 - val_accuracy: 0.5987
# Epoch 39/200
# 14/14 - 0s - loss: 0.6365 - accuracy: 0.6492 - val_loss: 0.6651 - val_accuracy: 0.5987
# Epoch 40/200
# 14/14 - 0s - loss: 0.6361 - accuracy: 0.6492 - val_loss: 0.6644 - val_accuracy: 0.5987
# Epoch 41/200
# 14/14 - 0s - loss: 0.6354 - accuracy: 0.6492 - val_loss: 0.6641 - val_accuracy: 0.5987
# Epoch 42/200
# 14/14 - 0s - loss: 0.6349 - accuracy: 0.6492 - val_loss: 0.6625 - val_accuracy: 0.5987
# Epoch 43/200
# 14/14 - 0s - loss: 0.6344 - accuracy: 0.6492 - val_loss: 0.6625 - val_accuracy: 0.5987
# Epoch 44/200
# 14/14 - 0s - loss: 0.6336 - accuracy: 0.6492 - val_loss: 0.6623 - val_accuracy: 0.5987
# Epoch 45/200
# 14/14 - 0s - loss: 0.6329 - accuracy: 0.6492 - val_loss: 0.6614 - val_accuracy: 0.5987
# Epoch 46/200
# 14/14 - 0s - loss: 0.6329 - accuracy: 0.6492 - val_loss: 0.6589 - val_accuracy: 0.5987
# Epoch 47/200
# 14/14 - 0s - loss: 0.6318 - accuracy: 0.6492 - val_loss: 0.6607 - val_accuracy: 0.5987
# Epoch 48/200
# 14/14 - 0s - loss: 0.6308 - accuracy: 0.6492 - val_loss: 0.6586 - val_accuracy: 0.5987
# Epoch 49/200
# 14/14 - 0s - loss: 0.6302 - accuracy: 0.6492 - val_loss: 0.6564 - val_accuracy: 0.5987
# Epoch 50/200
# 14/14 - 0s - loss: 0.6295 - accuracy: 0.6492 - val_loss: 0.6568 - val_accuracy: 0.5987
# Epoch 51/200
# 14/14 - 0s - loss: 0.6287 - accuracy: 0.6492 - val_loss: 0.6554 - val_accuracy: 0.5987
# Epoch 52/200
# 14/14 - 0s - loss: 0.6277 - accuracy: 0.6492 - val_loss: 0.6546 - val_accuracy: 0.5987
# Epoch 53/200
# 14/14 - 0s - loss: 0.6268 - accuracy: 0.6492 - val_loss: 0.6542 - val_accuracy: 0.5987
# Epoch 54/200
# 14/14 - 0s - loss: 0.6260 - accuracy: 0.6492 - val_loss: 0.6516 - val_accuracy: 0.5987
# Epoch 55/200
# 14/14 - 0s - loss: 0.6250 - accuracy: 0.6492 - val_loss: 0.6516 - val_accuracy: 0.5987
# Epoch 56/200
# 14/14 - 0s - loss: 0.6240 - accuracy: 0.6492 - val_loss: 0.6498 - val_accuracy: 0.5987
# Epoch 57/200
# 14/14 - 0s - loss: 0.6234 - accuracy: 0.6492 - val_loss: 0.6495 - val_accuracy: 0.5987
# Epoch 58/200
# 14/14 - 0s - loss: 0.6223 - accuracy: 0.6514 - val_loss: 0.6468 - val_accuracy: 0.5987
# Epoch 59/200
# 14/14 - 0s - loss: 0.6213 - accuracy: 0.6514 - val_loss: 0.6474 - val_accuracy: 0.5987
# Epoch 60/200
# 14/14 - 0s - loss: 0.6202 - accuracy: 0.6514 - val_loss: 0.6443 - val_accuracy: 0.6020
# Epoch 61/200
# 14/14 - 0s - loss: 0.6191 - accuracy: 0.6514 - val_loss: 0.6433 - val_accuracy: 0.6020
# Epoch 62/200
# 14/14 - 0s - loss: 0.6177 - accuracy: 0.6503 - val_loss: 0.6432 - val_accuracy: 0.6020
# Epoch 63/200
# 14/14 - 0s - loss: 0.6172 - accuracy: 0.6514 - val_loss: 0.6437 - val_accuracy: 0.6020
# Epoch 64/200
# 14/14 - 0s - loss: 0.6164 - accuracy: 0.6514 - val_loss: 0.6382 - val_accuracy: 0.6054
# Epoch 65/200
# 14/14 - 0s - loss: 0.6143 - accuracy: 0.6514 - val_loss: 0.6389 - val_accuracy: 0.6020
# Epoch 66/200
# 14/14 - 0s - loss: 0.6131 - accuracy: 0.6514 - val_loss: 0.6372 - val_accuracy: 0.6054
# Epoch 67/200
# 14/14 - 0s - loss: 0.6125 - accuracy: 0.6525 - val_loss: 0.6340 - val_accuracy: 0.6054
# Epoch 68/200
# 14/14 - 0s - loss: 0.6109 - accuracy: 0.6547 - val_loss: 0.6357 - val_accuracy: 0.6054
# Epoch 69/200
# 14/14 - 0s - loss: 0.6094 - accuracy: 0.6514 - val_loss: 0.6339 - val_accuracy: 0.6054
# Epoch 70/200
# 14/14 - 0s - loss: 0.6079 - accuracy: 0.6547 - val_loss: 0.6301 - val_accuracy: 0.6087
# Epoch 71/200
# 14/14 - 0s - loss: 0.6069 - accuracy: 0.6547 - val_loss: 0.6291 - val_accuracy: 0.6087
# Epoch 72/200
# 14/14 - 0s - loss: 0.6056 - accuracy: 0.6581 - val_loss: 0.6266 - val_accuracy: 0.6154
# Epoch 73/200
# 14/14 - 0s - loss: 0.6043 - accuracy: 0.6603 - val_loss: 0.6249 - val_accuracy: 0.6187
# Epoch 74/200
# 14/14 - 0s - loss: 0.6030 - accuracy: 0.6570 - val_loss: 0.6257 - val_accuracy: 0.6154
# Epoch 75/200
# 14/14 - 0s - loss: 0.6016 - accuracy: 0.6581 - val_loss: 0.6221 - val_accuracy: 0.6221
# Epoch 76/200
# 14/14 - 0s - loss: 0.6004 - accuracy: 0.6626 - val_loss: 0.6197 - val_accuracy: 0.6288
# Epoch 77/200
# 14/14 - 0s - loss: 0.5995 - accuracy: 0.6581 - val_loss: 0.6222 - val_accuracy: 0.6187
# Epoch 78/200
# 14/14 - 0s - loss: 0.5972 - accuracy: 0.6626 - val_loss: 0.6180 - val_accuracy: 0.6288
# Epoch 79/200
# 14/14 - 0s - loss: 0.5959 - accuracy: 0.6659 - val_loss: 0.6155 - val_accuracy: 0.6388
# Epoch 80/200
# 14/14 - 0s - loss: 0.5945 - accuracy: 0.6670 - val_loss: 0.6135 - val_accuracy: 0.6455
# Epoch 81/200
# 14/14 - 0s - loss: 0.5933 - accuracy: 0.6659 - val_loss: 0.6120 - val_accuracy: 0.6455
# Epoch 82/200
# 14/14 - 0s - loss: 0.5924 - accuracy: 0.6682 - val_loss: 0.6128 - val_accuracy: 0.6388
# Epoch 83/200
# 14/14 - 0s - loss: 0.5908 - accuracy: 0.6682 - val_loss: 0.6083 - val_accuracy: 0.6488
# Epoch 84/200
# 14/14 - 0s - loss: 0.5891 - accuracy: 0.6737 - val_loss: 0.6079 - val_accuracy: 0.6455
# Epoch 85/200
# 14/14 - 0s - loss: 0.5879 - accuracy: 0.6737 - val_loss: 0.6066 - val_accuracy: 0.6488
# Epoch 86/200
# 14/14 - 0s - loss: 0.5863 - accuracy: 0.6737 - val_loss: 0.6034 - val_accuracy: 0.6589
# Epoch 87/200
# 14/14 - 0s - loss: 0.5851 - accuracy: 0.6838 - val_loss: 0.6015 - val_accuracy: 0.6589
# Epoch 88/200
# 14/14 - 0s - loss: 0.5837 - accuracy: 0.6849 - val_loss: 0.6008 - val_accuracy: 0.6589
# Epoch 89/200
# 14/14 - 0s - loss: 0.5823 - accuracy: 0.6838 - val_loss: 0.5998 - val_accuracy: 0.6589
# Epoch 90/200
# 14/14 - 0s - loss: 0.5811 - accuracy: 0.6838 - val_loss: 0.5976 - val_accuracy: 0.6622
# Epoch 91/200
# 14/14 - 0s - loss: 0.5798 - accuracy: 0.6860 - val_loss: 0.5958 - val_accuracy: 0.6589
# Epoch 92/200
# 14/14 - 0s - loss: 0.5784 - accuracy: 0.6927 - val_loss: 0.5939 - val_accuracy: 0.6555
# Epoch 93/200
# 14/14 - 0s - loss: 0.5774 - accuracy: 0.6950 - val_loss: 0.5923 - val_accuracy: 0.6589
# Epoch 94/200
# 14/14 - 0s - loss: 0.5758 - accuracy: 0.6927 - val_loss: 0.5921 - val_accuracy: 0.6555
# Epoch 95/200
# 14/14 - 0s - loss: 0.5752 - accuracy: 0.6961 - val_loss: 0.5897 - val_accuracy: 0.6689
# Epoch 96/200
# 14/14 - 0s - loss: 0.5737 - accuracy: 0.6916 - val_loss: 0.5879 - val_accuracy: 0.6689
# Epoch 97/200
# 14/14 - 0s - loss: 0.5724 - accuracy: 0.6927 - val_loss: 0.5865 - val_accuracy: 0.6722
# Epoch 98/200
# 14/14 - 0s - loss: 0.5714 - accuracy: 0.6939 - val_loss: 0.5854 - val_accuracy: 0.6756
# Epoch 99/200
# 14/14 - 0s - loss: 0.5703 - accuracy: 0.6927 - val_loss: 0.5826 - val_accuracy: 0.6890
# Epoch 100/200
# 14/14 - 0s - loss: 0.5690 - accuracy: 0.6972 - val_loss: 0.5822 - val_accuracy: 0.6856
# Epoch 101/200
# 14/14 - 0s - loss: 0.5679 - accuracy: 0.6961 - val_loss: 0.5813 - val_accuracy: 0.6856
# Epoch 102/200
# 14/14 - 0s - loss: 0.5671 - accuracy: 0.6927 - val_loss: 0.5808 - val_accuracy: 0.6856
# Epoch 103/200
# 14/14 - 0s - loss: 0.5659 - accuracy: 0.6983 - val_loss: 0.5778 - val_accuracy: 0.6923
# Epoch 104/200
# 14/14 - 0s - loss: 0.5650 - accuracy: 0.7028 - val_loss: 0.5765 - val_accuracy: 0.6957
# Epoch 105/200
# 14/14 - 0s - loss: 0.5642 - accuracy: 0.6961 - val_loss: 0.5758 - val_accuracy: 0.6957
# Epoch 106/200
# 14/14 - 0s - loss: 0.5630 - accuracy: 0.7017 - val_loss: 0.5746 - val_accuracy: 0.6957
# Epoch 107/200
# 14/14 - 0s - loss: 0.5630 - accuracy: 0.6983 - val_loss: 0.5739 - val_accuracy: 0.6957
# Epoch 108/200
# 14/14 - 0s - loss: 0.5618 - accuracy: 0.7017 - val_loss: 0.5709 - val_accuracy: 0.7191
# Epoch 109/200
# 14/14 - 0s - loss: 0.5605 - accuracy: 0.7050 - val_loss: 0.5711 - val_accuracy: 0.7023
# Epoch 110/200
# 14/14 - 0s - loss: 0.5602 - accuracy: 0.6994 - val_loss: 0.5714 - val_accuracy: 0.6957
# Epoch 111/200
# 14/14 - 0s - loss: 0.5588 - accuracy: 0.7050 - val_loss: 0.5688 - val_accuracy: 0.7191
# Epoch 112/200
# 14/14 - 0s - loss: 0.5585 - accuracy: 0.7039 - val_loss: 0.5672 - val_accuracy: 0.7224
# Epoch 113/200
# 14/14 - 0s - loss: 0.5573 - accuracy: 0.7050 - val_loss: 0.5667 - val_accuracy: 0.7191
# Epoch 114/200
# 14/14 - 0s - loss: 0.5567 - accuracy: 0.7039 - val_loss: 0.5663 - val_accuracy: 0.7191
# Epoch 115/200
# 14/14 - 0s - loss: 0.5560 - accuracy: 0.7039 - val_loss: 0.5654 - val_accuracy: 0.7191
# Epoch 116/200
# 14/14 - 0s - loss: 0.5554 - accuracy: 0.7039 - val_loss: 0.5648 - val_accuracy: 0.7191
# Epoch 117/200
# 14/14 - 0s - loss: 0.5548 - accuracy: 0.7061 - val_loss: 0.5632 - val_accuracy: 0.7324
# Epoch 118/200
# 14/14 - 0s - loss: 0.5543 - accuracy: 0.7050 - val_loss: 0.5629 - val_accuracy: 0.7291
# Epoch 119/200
# 14/14 - 0s - loss: 0.5550 - accuracy: 0.7196 - val_loss: 0.5603 - val_accuracy: 0.7425
# Epoch 120/200
# 14/14 - 0s - loss: 0.5534 - accuracy: 0.7084 - val_loss: 0.5637 - val_accuracy: 0.7157
# Epoch 121/200
# 14/14 - 0s - loss: 0.5533 - accuracy: 0.7084 - val_loss: 0.5609 - val_accuracy: 0.7324
# Epoch 122/200
# 14/14 - 0s - loss: 0.5519 - accuracy: 0.7128 - val_loss: 0.5579 - val_accuracy: 0.7391
# Epoch 123/200
# 14/14 - 0s - loss: 0.5519 - accuracy: 0.7184 - val_loss: 0.5582 - val_accuracy: 0.7425
# Epoch 124/200
# 14/14 - 0s - loss: 0.5519 - accuracy: 0.7073 - val_loss: 0.5607 - val_accuracy: 0.7191
# Epoch 125/200
# 14/14 - 0s - loss: 0.5506 - accuracy: 0.7084 - val_loss: 0.5574 - val_accuracy: 0.7391
# Epoch 126/200
# 14/14 - 0s - loss: 0.5504 - accuracy: 0.7151 - val_loss: 0.5552 - val_accuracy: 0.7358
# Epoch 127/200
# 14/14 - 0s - loss: 0.5506 - accuracy: 0.7173 - val_loss: 0.5573 - val_accuracy: 0.7391
# Epoch 128/200
# 14/14 - 0s - loss: 0.5499 - accuracy: 0.7151 - val_loss: 0.5564 - val_accuracy: 0.7391
# Epoch 129/200
# 14/14 - 0s - loss: 0.5492 - accuracy: 0.7173 - val_loss: 0.5546 - val_accuracy: 0.7391
# Epoch 130/200
# 14/14 - 0s - loss: 0.5490 - accuracy: 0.7173 - val_loss: 0.5553 - val_accuracy: 0.7425
# Epoch 131/200
# 14/14 - 0s - loss: 0.5483 - accuracy: 0.7128 - val_loss: 0.5542 - val_accuracy: 0.7391
# Epoch 132/200
# 14/14 - 0s - loss: 0.5485 - accuracy: 0.7140 - val_loss: 0.5543 - val_accuracy: 0.7425
# Epoch 133/200
# 14/14 - 0s - loss: 0.5479 - accuracy: 0.7184 - val_loss: 0.5525 - val_accuracy: 0.7425
# Epoch 134/200
# 14/14 - 0s - loss: 0.5476 - accuracy: 0.7173 - val_loss: 0.5516 - val_accuracy: 0.7324
# Epoch 135/200
# 14/14 - 0s - loss: 0.5473 - accuracy: 0.7151 - val_loss: 0.5524 - val_accuracy: 0.7391
# Epoch 136/200
# 14/14 - 0s - loss: 0.5471 - accuracy: 0.7162 - val_loss: 0.5526 - val_accuracy: 0.7391
# Epoch 137/200
# 14/14 - 0s - loss: 0.5466 - accuracy: 0.7151 - val_loss: 0.5517 - val_accuracy: 0.7425
# Epoch 138/200
# 14/14 - 0s - loss: 0.5463 - accuracy: 0.7207 - val_loss: 0.5501 - val_accuracy: 0.7324
# Epoch 139/200
# 14/14 - 0s - loss: 0.5468 - accuracy: 0.7151 - val_loss: 0.5516 - val_accuracy: 0.7391
# Epoch 140/200
# 14/14 - 0s - loss: 0.5463 - accuracy: 0.7196 - val_loss: 0.5489 - val_accuracy: 0.7291
# Epoch 141/200
# 14/14 - 0s - loss: 0.5461 - accuracy: 0.7184 - val_loss: 0.5503 - val_accuracy: 0.7391
# Epoch 142/200
# 14/14 - 0s - loss: 0.5455 - accuracy: 0.7151 - val_loss: 0.5495 - val_accuracy: 0.7391
# Epoch 143/200
# 14/14 - 0s - loss: 0.5453 - accuracy: 0.7162 - val_loss: 0.5501 - val_accuracy: 0.7425
# Epoch 144/200
# 14/14 - 0s - loss: 0.5451 - accuracy: 0.7162 - val_loss: 0.5494 - val_accuracy: 0.7391
# Epoch 145/200
# 14/14 - 0s - loss: 0.5464 - accuracy: 0.7207 - val_loss: 0.5472 - val_accuracy: 0.7258
# Epoch 146/200
# 14/14 - 0s - loss: 0.5445 - accuracy: 0.7151 - val_loss: 0.5498 - val_accuracy: 0.7425
# Epoch 147/200
# 14/14 - 0s - loss: 0.5447 - accuracy: 0.7151 - val_loss: 0.5496 - val_accuracy: 0.7425
# Epoch 148/200
# 14/14 - 0s - loss: 0.5459 - accuracy: 0.7151 - val_loss: 0.5462 - val_accuracy: 0.7258
# Epoch 149/200
# 14/14 - 0s - loss: 0.5452 - accuracy: 0.7151 - val_loss: 0.5499 - val_accuracy: 0.7425
# Epoch 150/200
# 14/14 - 0s - loss: 0.5441 - accuracy: 0.7162 - val_loss: 0.5468 - val_accuracy: 0.7358
# Epoch 151/200
# 14/14 - 0s - loss: 0.5440 - accuracy: 0.7184 - val_loss: 0.5463 - val_accuracy: 0.7291
# Epoch 152/200
# 14/14 - 0s - loss: 0.5437 - accuracy: 0.7207 - val_loss: 0.5463 - val_accuracy: 0.7358
# Epoch 153/200
# 14/14 - 0s - loss: 0.5441 - accuracy: 0.7173 - val_loss: 0.5486 - val_accuracy: 0.7425
# Epoch 154/200
# 14/14 - 0s - loss: 0.5438 - accuracy: 0.7128 - val_loss: 0.5469 - val_accuracy: 0.7358
# Epoch 155/200
# 14/14 - 0s - loss: 0.5444 - accuracy: 0.7196 - val_loss: 0.5441 - val_accuracy: 0.7291
# Epoch 156/200
# 14/14 - 0s - loss: 0.5432 - accuracy: 0.7218 - val_loss: 0.5462 - val_accuracy: 0.7358
# Epoch 157/200
# 14/14 - 0s - loss: 0.5430 - accuracy: 0.7184 - val_loss: 0.5472 - val_accuracy: 0.7391
# Epoch 158/200
# 14/14 - 0s - loss: 0.5432 - accuracy: 0.7184 - val_loss: 0.5453 - val_accuracy: 0.7358
# Epoch 159/200
# 14/14 - 0s - loss: 0.5431 - accuracy: 0.7207 - val_loss: 0.5456 - val_accuracy: 0.7358
# Epoch 160/200
# 14/14 - 0s - loss: 0.5427 - accuracy: 0.7196 - val_loss: 0.5454 - val_accuracy: 0.7358
# Epoch 161/200
# 14/14 - 0s - loss: 0.5436 - accuracy: 0.7240 - val_loss: 0.5441 - val_accuracy: 0.7324
# Epoch 162/200
# 14/14 - 0s - loss: 0.5443 - accuracy: 0.7140 - val_loss: 0.5465 - val_accuracy: 0.7358
# Epoch 163/200
# 14/14 - 0s - loss: 0.5432 - accuracy: 0.7218 - val_loss: 0.5434 - val_accuracy: 0.7291
# Epoch 164/200
# 14/14 - 0s - loss: 0.5426 - accuracy: 0.7207 - val_loss: 0.5453 - val_accuracy: 0.7358
# Epoch 165/200
# 14/14 - 0s - loss: 0.5427 - accuracy: 0.7218 - val_loss: 0.5443 - val_accuracy: 0.7324
# Epoch 166/200
# 14/14 - 0s - loss: 0.5429 - accuracy: 0.7173 - val_loss: 0.5455 - val_accuracy: 0.7358
# Epoch 167/200
# 14/14 - 0s - loss: 0.5420 - accuracy: 0.7196 - val_loss: 0.5434 - val_accuracy: 0.7324
# Epoch 168/200
# 14/14 - 0s - loss: 0.5421 - accuracy: 0.7240 - val_loss: 0.5432 - val_accuracy: 0.7324
# Epoch 169/200
# 14/14 - 0s - loss: 0.5428 - accuracy: 0.7229 - val_loss: 0.5428 - val_accuracy: 0.7391
# Epoch 170/200
# 14/14 - 0s - loss: 0.5423 - accuracy: 0.7218 - val_loss: 0.5429 - val_accuracy: 0.7324
# Epoch 171/200
# 14/14 - 0s - loss: 0.5424 - accuracy: 0.7162 - val_loss: 0.5455 - val_accuracy: 0.7358
# Epoch 172/200
# 14/14 - 0s - loss: 0.5418 - accuracy: 0.7196 - val_loss: 0.5437 - val_accuracy: 0.7358
# Epoch 173/200
# 14/14 - 0s - loss: 0.5419 - accuracy: 0.7240 - val_loss: 0.5423 - val_accuracy: 0.7391
# Epoch 174/200
# 14/14 - 0s - loss: 0.5422 - accuracy: 0.7207 - val_loss: 0.5438 - val_accuracy: 0.7358
# Epoch 175/200
# 14/14 - 0s - loss: 0.5416 - accuracy: 0.7240 - val_loss: 0.5431 - val_accuracy: 0.7358
# Epoch 176/200
# 14/14 - 0s - loss: 0.5419 - accuracy: 0.7229 - val_loss: 0.5421 - val_accuracy: 0.7425
# Epoch 177/200
# 14/14 - 0s - loss: 0.5415 - accuracy: 0.7240 - val_loss: 0.5433 - val_accuracy: 0.7358
# Epoch 178/200
# 14/14 - 0s - loss: 0.5416 - accuracy: 0.7207 - val_loss: 0.5441 - val_accuracy: 0.7358
# Epoch 179/200
# 14/14 - 0s - loss: 0.5419 - accuracy: 0.7218 - val_loss: 0.5418 - val_accuracy: 0.7425
# Epoch 180/200
# 14/14 - 0s - loss: 0.5415 - accuracy: 0.7240 - val_loss: 0.5427 - val_accuracy: 0.7358
# Epoch 181/200
# 14/14 - 0s - loss: 0.5414 - accuracy: 0.7218 - val_loss: 0.5439 - val_accuracy: 0.7358
# Epoch 182/200
# 14/14 - 0s - loss: 0.5418 - accuracy: 0.7184 - val_loss: 0.5435 - val_accuracy: 0.7358
# Epoch 183/200
# 14/14 - 0s - loss: 0.5413 - accuracy: 0.7240 - val_loss: 0.5414 - val_accuracy: 0.7324
# Epoch 184/200
# 14/14 - 0s - loss: 0.5417 - accuracy: 0.7240 - val_loss: 0.5413 - val_accuracy: 0.7324
# Epoch 185/200
# 14/14 - 0s - loss: 0.5411 - accuracy: 0.7240 - val_loss: 0.5428 - val_accuracy: 0.7358
# Epoch 186/200
# 14/14 - 0s - loss: 0.5411 - accuracy: 0.7229 - val_loss: 0.5422 - val_accuracy: 0.7358
# Epoch 187/200
# 14/14 - 0s - loss: 0.5413 - accuracy: 0.7229 - val_loss: 0.5432 - val_accuracy: 0.7358
# Epoch 188/200
# 14/14 - 0s - loss: 0.5418 - accuracy: 0.7274 - val_loss: 0.5412 - val_accuracy: 0.7358
# Epoch 189/200
# 14/14 - 0s - loss: 0.5435 - accuracy: 0.7173 - val_loss: 0.5451 - val_accuracy: 0.7358
# Epoch 190/200
# 14/14 - 0s - loss: 0.5415 - accuracy: 0.7274 - val_loss: 0.5402 - val_accuracy: 0.7224
# Epoch 191/200
# 14/14 - 0s - loss: 0.5415 - accuracy: 0.7251 - val_loss: 0.5423 - val_accuracy: 0.7391
# Epoch 192/200
# 14/14 - 0s - loss: 0.5410 - accuracy: 0.7229 - val_loss: 0.5423 - val_accuracy: 0.7391
# Epoch 193/200
# 14/14 - 0s - loss: 0.5409 - accuracy: 0.7240 - val_loss: 0.5414 - val_accuracy: 0.7391
# Epoch 194/200
# 14/14 - 0s - loss: 0.5408 - accuracy: 0.7251 - val_loss: 0.5414 - val_accuracy: 0.7358
# Epoch 195/200
# 14/14 - 0s - loss: 0.5414 - accuracy: 0.7218 - val_loss: 0.5432 - val_accuracy: 0.7358
# Epoch 196/200
# 14/14 - 0s - loss: 0.5424 - accuracy: 0.7285 - val_loss: 0.5400 - val_accuracy: 0.7191
# Epoch 197/200
# 14/14 - 0s - loss: 0.5409 - accuracy: 0.7240 - val_loss: 0.5431 - val_accuracy: 0.7358
# Epoch 198/200
# 14/14 - 0s - loss: 0.5411 - accuracy: 0.7229 - val_loss: 0.5411 - val_accuracy: 0.7425
# Epoch 199/200
# 14/14 - 0s - loss: 0.5406 - accuracy: 0.7240 - val_loss: 0.5416 - val_accuracy: 0.7425
# Epoch 200/200
# 14/14 - 0s - loss: 0.5406 - accuracy: 0.7229 - val_loss: 0.5421 - val_accuracy: 0.7358
# Accuracy: 0.7333333333333333
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                448
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,537
# Trainable params: 1,537
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#leftover code on how to make a set of predictions, the function returns a probability as to how likely it believes the person is septic
#uncomment the string literal to make this work
'''
dfnv_x = df.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)
dfnv_y = df['Bacterial sepsis using Sepsis-3 criteria (yes/no)']
X_train, X_test, y_train, y_test = train_test_split(dfnv_x, dfnv_y, test_size=0.25, random_state = 10000)  
trainxr = X_train.values.astype('float32')
testxr = X_test.values.astype('float32')
trainy = y_train.values.astype('float32')
testy = y_test.values.astype('float32')

prediction_vector = np.around(nn_model.predict(testxr))
prediction_vector
'''
# Out:
# "\ndfnv_x = df.drop('Bacterial sepsis using Sepsis-3 criteria (yes/no)',axis=1)\ndfnv_y = df['Bacterial sepsis using Sepsis-3 criteria (yes/no)']\nX_train, X_test, y_train, y_test = train_test_split(dfnv_x, dfnv_y, test_size=0.25, random_state = 10000)  \ntrainxr = X_train.values.astype('float32')\ntestxr = X_test.values.astype('float32')\ntrainy = y_train.values.astype('float32')\ntesty = y_test.values.astype('float32')\n\nprediction_vector = np.around(nn_model.predict(testxr))\nprediction_vector\n"
